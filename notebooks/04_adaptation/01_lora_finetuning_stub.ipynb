# %% [markdown]
# # Adaptation: LoRA Fine-Tuning
#
# This workspace is used for testing parameter-efficient fine-tuning (PEFT) on low-resource datasets.
# After fine-tuning, the resulting adapter weights should be registered as a new `Resource` in the Registry.
