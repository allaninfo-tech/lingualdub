# %% [markdown]
# # Baseline Dubbing Pipeline
#
# This notebook demonstrates how to wire together a basic end-to-end pipeline: ASR -> Translation -> TTS.
# It uses the Pipeline object to connect components and verify compatibility before execution.

# %%
from lingualdub.core.pipeline import Pipeline
from lingualdub.pipeline.executor import PipelineExecutor
from lingualdub.core.resource import Resource, ResourceKind

# Note: Actual component imports will go here once implemented.
# from lingualdub.components.asr.whisper import WhisperASR
# from lingualdub.components.translation.nllb import NLLBTranslation
# from lingualdub.components.tts.xtts import XTTSComponent

print("Ready to build the baseline pipeline.")

# %% [markdown]
# ## 1. Assemble the Pipeline
#
# We define the stages. The pipeline validates that `requires` and `provides` match across stages.

# %%
# asr = WhisperASR()
# mt = NLLBTranslation()
# tts = XTTSComponent()

# pipeline = Pipeline(
#     stages=[asr, mt, tts],
#     source_language="lug",
#     target_language="eng",
#     per_segment_language=True
# )
# print(pipeline)

# %% [markdown]
# ## 2. Execute
#
# Pass a Resource (audio file) into the PipelineExecutor.

# %%
# audio_input = Resource(id="test_audio_1", kind=ResourceKind.SPEECH, language="lug", version="1.0.0", path="/path/to/audio.wav")
# executor = PipelineExecutor(pipeline)
# final_result = executor.run(audio_input)

# print(f"Result status: {final_result.status}")
# print(f"Generated artifacts: {final_result.artifacts}")
