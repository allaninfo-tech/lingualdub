# %% [markdown]
# # Pipeline Comparison & Evaluation
#
# Use this notebook to run `EvaluatorComponent` instances on the outputs of different pipeline runs.
# Because each `Result` carries strict provenance (versions, run IDs), comparing results is deterministic.
